# %% [markdown]
# <a href="https://colab.research.google.com/github/hiyoman/ai/blob/main/Untitled%EC%B5%9C%EC%8B%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
import io
import pandas as pd
# Out:
#      <input type="file" id="files-3ca0f71f-8677-4656-9f8a-86f02985c6c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ca0f71f-8677-4656-9f8a-86f02985c6c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 도로살얼음 데이터정리1.csv to 도로살얼음 데이터정리1 (1).csv

# %%
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
import numpy as np
df = pd.read_csv(io.StringIO(uploaded['도로살얼음 데이터정리1.csv'].decode('cp949')))

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
train_set, test_set = train_test_split(df, test_size=0.3, random_state=1006)

print(len(train_set), len(test_set))
# Out:
# 136966 58700

# %%
target = df.노면상태

# %%
df = df.drop(['노면상태','YYMMDD','HHMMSS',], axis = 1)

# %%
train_set = train_set.drop('노면상태', axis = 1)

# %%
train_set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1b17ab7df3fb> in <module>()
# ----> 1 train_set
#
# NameError: name 'train_set' is not defined

# %%
target
# Out:
# 0         Dry
# 1         Dry
# 2         Dry
# 3         Dry
# 4         Dry
#          ...
# 195661    Dry
# 195662    Dry
# 195663    Dry
# 195664    Dry
# 195665    Dry
# Name: 노면상태, Length: 195666, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.3, random_state=1)

# %%
X_test
# Out:
#            풍향   풍속  대기온도  대기습도  ...  시간 강수량  6시간 누적 강수량     노면상대습도      마찰계수
# 97979     2.0  1.0  -3.3  45.2  ...     0.0        0.00   0.036397  0.820000
# 21525   339.0  4.7   0.3  28.9  ...     0.0        0.00   0.072316  0.820000
# 129919  316.0  1.8   9.4  58.9  ...     0.0        0.00   4.911465  0.816319
# 10272   324.0  4.6   2.5  73.7  ...     0.0        0.01  88.600070  0.813920
# 71495   315.0  0.9   6.8  82.6  ...     0.0        0.04  66.574230  0.796224
# ...       ...  ...   ...   ...  ...     ...         ...        ...       ...
# 34273   318.0  3.0   3.3  59.5  ...     0.0        0.00  28.087880  0.820000
# 25569   295.0  1.3  -0.7  45.6  ...     0.0        0.00   0.050970  0.820000
# 144683  303.0  2.5   9.4  48.0  ...     0.0        0.00  10.077290  0.815161
# 129712  339.0  0.5   1.7  85.8  ...     0.0        0.00  60.305620  0.809750
# 130075  319.0  2.9  13.7  37.5  ...     0.0        0.00   0.134882  0.817098
#
# [58700 rows x 10 columns]

# %%
forest = RandomForestClassifier(n_estimators=100)
forest.fit(X_train, y_train)

# %%
y_pred = forest.predict(X_test)

# %%
print(y_pred)
print(list(y_test))
# Out:
# ['Dry' 'Dry' 'Dry' ... 'Damp' 'Damp' 'Dry']
# ...

# %%
print('정확도 :', metrics.accuracy_score(y_test, y_pred))
# Out:
# 정확도 : 0.999114139693356

# %%
X_test
# Out:
#            풍향   풍속  대기온도  대기습도  ...  시간 강수량  6시간 누적 강수량     노면상대습도      마찰계수
# 97979     2.0  1.0  -3.3  45.2  ...     0.0        0.00   0.036397  0.820000
# 21525   339.0  4.7   0.3  28.9  ...     0.0        0.00   0.072316  0.820000
# 129919  316.0  1.8   9.4  58.9  ...     0.0        0.00   4.911465  0.816319
# 10272   324.0  4.6   2.5  73.7  ...     0.0        0.01  88.600070  0.813920
# 71495   315.0  0.9   6.8  82.6  ...     0.0        0.04  66.574230  0.796224
# ...       ...  ...   ...   ...  ...     ...         ...        ...       ...
# 34273   318.0  3.0   3.3  59.5  ...     0.0        0.00  28.087880  0.820000
# 25569   295.0  1.3  -0.7  45.6  ...     0.0        0.00   0.050970  0.820000
# 144683  303.0  2.5   9.4  48.0  ...     0.0        0.00  10.077290  0.815161
# 129712  339.0  0.5   1.7  85.8  ...     0.0        0.00  60.305620  0.809750
# 130075  319.0  2.9  13.7  37.5  ...     0.0        0.00   0.134882  0.817098
#
# [58700 rows x 10 columns]

# %%
from sklearn.metrics import accuracy_score
rf_clf1 = RandomForestClassifier(n_estimators = 100, 
                                max_depth = 11,
                                min_samples_leaf = 8,
                                min_samples_split = 8,
                                random_state = 0,
                                n_jobs = -1)
rf_clf1.fit(X_train, y_train)
pred = rf_clf1.predict(X_test)
print('예측 정확도: {:.4f}'.format(accuracy_score(y_test,pred)))
# Out:
# 예측 정확도: 0.9979

# %%
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ftr_importances_values = rf_clf1.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index = X_train.columns)
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(9,7))
plt.title('Top 20 Feature Importances')
sns.barplot(x=ftr_top20, y=ftr_top20.index)
plt.show()

# %%
X_test

# %%
len(pred)

# %%
X_test = X_test.drop(['HHMMSS','YYMMDD'], axis = 1)

# %%
len(X_test)

# %%
print( isinstance(pred, dict) )

# %%
col_name = ['노면상태']
df = pd.DataFrame(pred, columns=col_name)

# %%
df

# %%
result3

# %%
data = X_test.drop(['풍향','풍속','대기온도','기압','노면온도','시간 강수량','6시간 누적 강수량','노면상대습도'], axis = 1)

# %%
a = pd.concat([data,df],axis=1)

# %%
data.reset_index(drop=True, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
a = pd.concat([data,df],axis=1)

# %%
a

# %%
x_train, x_test, Y_train, Y_test = train_test_split(data, df, test_size=0.4, random_state=1)

# %%
from sklearn.metrics import accuracy_score
rf_clf2 = RandomForestClassifier(n_estimators = 100, 
                                max_depth = 11,
                                min_samples_leaf = 8,
                                min_samples_split = 8,
                                random_state = 0,
                                n_jobs = -1)
rf_clf2.fit(x_train, Y_train)
pred1 = rf_clf2.predict(x_test)
print('예측 정확도: {:.4f}'.format(accuracy_score(Y_test,pred1)))

# %%
X_test

# %%
d = X_test.drop('마찰계수', axis = 1)

# %%
d

# %%
c_train, c_test, d_train, d_test = train_test_split(d, df, test_size=0.4, random_state=1)

# %%
a_train

# %%
from sklearn.metrics import accuracy_score
rf_clf3 = RandomForestClassifier(n_estimators = 100, 
                                max_depth = 12,
                                min_samples_leaf = 10,
                                min_samples_split = 10,
                                random_state = 0,
                                n_jobs = -1)
rf_clf3.fit(c_train, d_train)
pred2 = rf_clf3.predict(c_test)
print('예측 정확도: {:.4f}'.format(accuracy_score(d_test,pred2)))
